# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
csv_file = '../dataset/multivariate/oisst_lat_14.0_lon_112.0.csv'
df = pd.read_csv(csv_file)
df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)
df
# Out:
#                   mslp        slhf        sshf        ssr        str  \
# date
# 1981-09-01  100747.010  -469802.38  -13879.336  965253.20 -164621.73
# 1981-09-02  100798.820  -432472.60  -22769.412  891725.60 -163932.03
# 1981-09-03  100762.600  -482590.75  -27607.145  936436.06 -171049.70
# 1981-09-04  100770.660  -458046.20  -27206.750  988204.44 -192117.78
# 1981-09-05  100890.590  -459249.34  -31879.484  971465.00 -187425.23
# ...                ...         ...         ...        ...        ...
# 2022-12-27  101458.445  -821170.60  -84925.490  601846.30 -193655.72
# 2022-12-28  101453.266  -613362.40  -43964.723  549188.10 -168267.80
# 2022-12-29  101532.086  -716134.44  -93106.234  227806.08 -118894.41
# 2022-12-30  101582.984 -1115293.40 -146360.000  427357.25 -150902.94
# 2022-12-31  101481.880  -791700.50  -97513.440  175114.90  -96161.06
#
#                  z500       z850        w10     wz500      wz850        sst
# date
# ...

# %%
sst = df['sst'][:]
plt.figure(figsize=(30, 6))
sns.lineplot(data=sst, color='#646464', linewidth=6)
# plt.axis('off')
plt.show()
# plt.savefig('sst.png', bbox_inches='tight', pad_inches=0)

# %%
mslp = df['mslp'][:]
plt.figure(figsize=(30, 6))
sns.lineplot(data=mslp, linewidth=1)
# plt.axis('off')
plt.show()
# plt.savefig('sst.png', bbox_inches='tight', pad_inches=0)

# %%
slhf = df['slhf'][:]
plt.figure(figsize=(30, 6))
sns.lineplot(data=slhf, linewidth=1)
# plt.axis('off')
plt.show()
# plt.savefig('sst.png', bbox_inches='tight', pad_inches=0)

# %%
sshf = df['sshf'][:]
plt.figure(figsize=(30, 6))
sns.lineplot(data=sshf, linewidth=1)
# plt.axis('off')
plt.show()
# plt.savefig('sst.png', bbox_inches='tight', pad_inches=0)

# %%
ssr = df['ssr'][:]
plt.figure(figsize=(30, 6))
sns.lineplot(data=ssr, linewidth=1)
# plt.axis('off')
plt.show()
# plt.savefig('sst.png', bbox_inches='tight', pad_inches=0)

# %%
str = df['str'][:]
plt.figure(figsize=(30, 6))
sns.lineplot(data=str, linewidth=1)
# plt.axis('off')
plt.show()
# plt.savefig('sst.png', bbox_inches='tight', pad_inches=0)

# %%
w10 = df['w10'][:]
plt.figure(figsize=(30, 6))
sns.lineplot(data=w10, linewidth=1)
# plt.axis('off')
plt.show()
# plt.savefig('sst.png', bbox_inches='tight', pad_inches=0)

# %%
wz500 = df['wz500'][:]
plt.figure(figsize=(30, 6))
sns.lineplot(data=wz500, linewidth=1)
# plt.axis('off')
plt.show()
# plt.savefig('sst.png', bbox_inches='tight', pad_inches=0)

# %%
z500 = df['z500'][:]
plt.figure(figsize=(30, 6))
sns.lineplot(data=z500, linewidth=1)
# plt.axis('off')
plt.show()
# plt.savefig('sst.png', bbox_inches='tight', pad_inches=0)

# %%
wz850 = df['wz850'][:]
plt.figure(figsize=(30, 6))
sns.lineplot(data=wz850, linewidth=1)
# plt.axis('off')
plt.show()
# plt.savefig('sst.png', bbox_inches='tight', pad_inches=0)

# %%
z850 = df['z850'][:]
plt.figure(figsize=(30, 6))
sns.lineplot(data=z850, linewidth=1)
# plt.axis('off')
plt.show()
# plt.savefig('sst.png', bbox_inches='tight', pad_inches=0)
